# %%
import pandas as pd
df = pd.read_excel('Pune Server Delivery data 01 Jan 2020- 30 Aug 2024.xlsx')

# %%
df.columns
# Out:
# Index(['City', 'delivery_date', 'product', 'total_quantity'], dtype='object')

# %%
df['product'].unique()
# Out:
# array(['A2 1L', 'A2 Ghee', 'A2 Gir Cow Paneer 200g', 'A2 Value Pack 1L',
#        'Buffalo Ghee 500ml', 'Buffalo Milk 1L', 'Chocolate Milk 0.3L',
#        'Chocolate Milk 300ml', 'Curd Culture', 'Ghee 500ml',
#        'Kharwas 120g', 'Paneer 200g Cows Milk', 'Past Milk 0.5L',
#        'Past Milk 1L', 'Raw Milk 1L', 'New A2 Value Pack 500ml',
#        'Insulated Door Bag', 'Buffalo Milk Value Pack 500ml',
#        'Tender Coconut', 'Dahi', 'Lactose Free Milk 0.5L',
#        'Past Milk Value Pack 1L', 'Raw Value Pack 1L',
#        'Buffalo Value Pack 1L', 'Past Milk Value Pack 0.5L',
#        'Raw Milk Value Pack 0.5L', 'A2 Ghee - Gift Pack',
#        'Homogenised A2 1L'], dtype=object)

# %%
df['product'].value_counts()
# Out:
# product
# A2 1L                            1704
# A2 Value Pack 1L                 1704
# Buffalo Milk 1L                  1704
# Past Milk 1L                     1704
# Raw Milk 1L                      1704
# A2 Ghee                          1672
# A2 Gir Cow Paneer 200g           1665
# New A2 Value Pack 500ml          1640
# Ghee 500ml                       1639
# Curd Culture                     1606
# Kharwas 120g                     1469
# Paneer 200g Cows Milk            1449
# Buffalo Milk Value Pack 500ml    1262
# Buffalo Ghee 500ml               1203
# Dahi                             1107
# Past Milk 0.5L                    946
# Raw Value Pack 1L                 800
# Past Milk Value Pack 1L           800
# Lactose Free Milk 0.5L            795
# Insulated Door Bag                794
# Buffalo Value Pack 1L             790
# Past Milk Value Pack 0.5L         696
# Raw Milk Value Pack 0.5L          696
# Tender Coconut                    386
# ...

# %%
import matplotlib.pyplot as plt

# Convert 'delivery_date' to datetime format
df['delivery_date'] = pd.to_datetime(df['delivery_date'],format="%d-%m-%Y")

# Get unique product names
products = df['product'].unique()

# Create a plot for each product
for product in products:
    product_df = df[df['product'] == product]  # Filter data for the current product
    product_df = product_df.sort_values('delivery_date')  # Sort data by date
    
    # Plotting
    plt.figure(figsize=(10, 6))
    plt.plot(product_df['delivery_date'], product_df['total_quantity'], marker='o', linestyle='-')
    plt.title(f'Trend of Total Quantity for {product} (2020-2024)')
    plt.xlabel('Date')
    plt.ylabel('Total Quantity')
    plt.xticks(rotation=45)  # Rotating x-axis labels for better readability
    plt.grid(True)
    plt.tight_layout()
    plt.show()
