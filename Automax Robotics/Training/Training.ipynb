# %%
# !nvidia-smi
# Out:
# Sun Aug 11 14:07:36 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.70                 Driver Version: 560.70         CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   40C    P3             19W /   50W |       0MiB /   6144MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.44  Python-3.8.19 torch-2.2.2 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# Setup complete  (20 CPUs, 15.7 GB RAM, 325.2/450.1 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=Data/data.yaml epochs=50 imgsz=640 plots=True

# %%
Image(filename=f'runs/detect/train2/confusion_matrix.png')

# %%
Image(filename=f'runs/detect/train2/results.png')

# %%
Image(filename=f'runs/detect/train2/val_batch1_pred.jpg')

# %%
# !yolo task=detect mode=val model=runs/detect/train2/weights/best.pt data=Data/data.yaml
